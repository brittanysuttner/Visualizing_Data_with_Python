# %% [markdown]
# # Practice notebook for univariate analysis using NHANES data
#
# This notebook will give you the opportunity to perform some univariate analyses on your own using the NHANES.  These analyses are similar to what was done in the week 2 NHANES case study notebook.
#
# You can enter your code into the cells that say "enter your code here", and you can type responses to the questions into the cells that say "Type Markdown and Latex".
#
# Note that most of the code that you will need to write below is very similar to code that appears in the case study notebook.  You will need to edit code from that notebook in small ways to adapt it to the prompts below.
#
# To get started, we will use the same module imports and read the data in the same way as we did in the case study:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import numpy as np

da = pd.read_csv("nhanes_2015_2016.csv")

# %% [markdown]
# ## Question 1
#
# Relabel the marital status variable [DMDMARTL](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#DMDMARTL) to have brief but informative character labels.  Then construct a frequency table of these values for all people, then for women only, and for men only.  Then construct these three frequency tables using only people whose age is between 30 and 40.
# 1=married, 2=widowed, 3=divorced, 4=separated, 5=never married, 6= living with partner, 77=refused, nan=missing

# %%
# insert your code here.
new_names = {1.:"mrrd",  3.:"divorced",  6.:"live with partner",  4.:"separated",  5.:"never mrrd",  2.:"widowed", 77.:"refused"}
Marital_status = da["DMDMARTL"].dropna()
Marital_status=Marital_status.replace(new_names)

sns.countplot(Marital_status).set_title("Marital Status")
plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
#Grab the WOMEN and MEN only rows for Marital Status. 1=Male, 2=Female
F_marital_status = da.loc[da['RIAGENDR']== 2]['DMDMARTL'].dropna()
M_marital_status = da.loc[da['RIAGENDR']== 1]['DMDMARTL'].dropna()

#Convert the same nomenclature as above:
M_marital_status=M_marital_status.replace(new_names).sort_values()
F_marital_status=F_marital_status.replace(new_names).sort_values()

#Make Frequency tables:
plt.xticks(rotation=-45)
sns.countplot(F_marital_status).set_title("Marital Status: Females")
# Out:
# Text(0.5,1,'Marital Status: Females')

# %%
sns.countplot(M_marital_status).set_title("Marital Status: Males")
plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
# Marital status for people between 30 and 40 only
#Get the rows of da for people between 30 and 40; AND only columns Marital status and gender:
db = da.loc[(da['RIDAGEYR'] >=30) & (da['RIDAGEYR'] <= 40)].loc[:,['DMDMARTL','RIAGENDR']]

#Plot the total for BOTH sexes:
db

#sns.countplot(Marital_status).set_title("Marital Status")
#plt.xticks(rotation=-45)
# Out:
#       DMDMARTL  RIAGENDR
# 7          1.0         2
# 12         6.0         2
# 34         1.0         2
# 50         1.0         2
# 61         1.0         2
# 64         1.0         1
# 65         1.0         2
# 68         1.0         1
# 70         5.0         1
# 73         6.0         2
# 79         1.0         2
# 82         1.0         2
# 99         6.0         1
# 110        4.0         1
# 112        6.0         2
# 120        1.0         2
# 135        1.0         1
# 144        1.0         1
# 147        5.0         2
# 154        5.0         2
# 162        1.0         1
# 180        1.0         1
# 183        1.0         1
# 197        5.0         1
# 199        5.0         2
# 205        6.0         1
# 216        5.0         1
# 233        1.0         1
# 241        5.0         2
# 253        1.0         2
# ...        ...       ...
# 5544       1.0         1
# 5547       3.0         1
# 5551       1.0         1
# 5552       5.0         2
# 5553       1.0         1
# ...

# %% [markdown]
# __Q1a.__ Briefly comment on some of the differences that you observe between the distribution of marital status between women and men, for people of all ages.

# %% [markdown]
# __Q1b.__ Briefly comment on the differences that you observe between the distribution of marital status states for women between the overall population, and for women between the ages of 30 and 40.

# %% [markdown]
# __Q1c.__ Repeat part b for the men.

# %% [markdown]
# ## Question 2
#
# Restricting to the female population, stratify the subjects into age bands no wider than ten years, and construct the distribution of marital status within each age band.  Within each age band, present the distribution in terms of proportions that must sum to 1.

# %%
# insert your code here

# %% [markdown]
# __Q2a.__ Comment on the trends that you see in this series of marginal distributions.

# %% [markdown]
# __Q2b.__ Repeat the construction for males.

# %%
# insert your code here

# %% [markdown]
# __Q2c.__ Comment on any notable differences that you see when comparing these results for females and for males.

# %% [markdown]
# ## Question 3
#
# Construct a histogram of the distribution of heights using the BMXHT variable in the NHANES sample.

# %%
# insert your code here

# %% [markdown]
# __Q3a.__ Use the `bins` argument to [distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) to produce histograms with different numbers of bins.  Assess whether the default value for this argument gives a meaningful result, and comment on what happens as the number of bins grows excessively large or excessively small.

# %% [markdown]
# __Q3b.__ Make separate histograms for the heights of women and men, then make a side-by-side boxplot showing the heights of women and men.

# %%
# insert your code here

# %% [markdown]
# __Q3c.__ Comment on what features, if any are not represented clearly in the boxplots, and what features, if any, are easier to see in the boxplots than in the histograms.

# %% [markdown]
# ## Question 4
#
# Make a boxplot showing the distribution of within-subject differences between the first and second systolic blood pressure measurents ([BPXSY1](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPX_I.htm#BPXSY1) and [BPXSY2](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPX_I.htm#BPXSY2)).

# %%
# insert your code here

# %% [markdown]
# __Q4a.__ What proportion of the subjects have a lower SBP on the second reading compared to the first?

# %%
# insert your code here

# %% [markdown]
# __Q4b.__ Make side-by-side boxplots of the two systolic blood pressure variables.

# %%
# insert your code here

# %% [markdown]
# __Q4c.__ Comment on the variation within either the first or second systolic blood pressure measurements, and the variation in the within-subject differences between the first and second systolic blood pressure measurements.

# %% [markdown]
# ## Question 5
#
# Construct a frequency table of household sizes for people within each educational attainment category (the relevant variable is [DMDEDUC2](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#DMDEDUC2)).  Convert the frequencies to proportions.

# %%
# insert your code here

# %% [markdown]
# __Q5a.__ Comment on any major differences among the distributions.

# %% [markdown]
# __Q5b.__ Restrict the sample to people between 30 and 40 years of age.  Then calculate the median household size for women and men within each level of educational attainment.

# %%
# insert your code here

# %% [markdown]
# ## Question 6
#
# The participants can be clustered into "maked variance units" (MVU) based on every combination of the variables [SDMVSTRA](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#SDMVSTRA) and [SDMVPSU](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#SDMVPSU).  Calculate the mean age ([RIDAGEYR](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#RIDAGEYR)), height ([BMXHT](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BMX_I.htm#BMXHT)), and BMI ([BMXBMI](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BMX_I.htm#BMXBMI)) for each gender ([RIAGENDR](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm#RIAGENDR)), within each MVU, and report the ratio between the largest and smallest mean (e.g. for height) across the MVUs.

# %%
# insert your code here

# %% [markdown]
# __Q6a.__ Comment on the extent to which mean age, height, and BMI vary among the MVUs.

# %% [markdown]
# __Q6b.__ Calculate the inter-quartile range (IQR) for age, height, and BMI for each gender and each MVU.  Report the ratio between the largest and smalles IQR across the MVUs.

# %%
# insert your code here

# %% [markdown]
# __Q6c.__ Comment on the extent to which the IQR for age, height, and BMI vary among the MVUs.
